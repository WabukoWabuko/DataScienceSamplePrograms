# %%
import numpy as np
import pandas as pd
import matplotlib as mlp
import matplotlib.pyplot as plt
import seaborn as sns

# %%
test = pd.DataFrame({
    "FirstNames": ["Wabuko", "Adams", "Trenda", "Amanda", "Raymond"],
    "SecondNames": ["Basil", "Phil", "Sherry", "Lynn", "Malachi"],
    "Age": [21, 26, 55, 19, 69],
    "HighSchools": ["Mabole", "Butere", "Mukumu", "Nyabururu", "Nairobi"]
    
}, index=["A", "B", "C", "D", "E"])
test
# Out:
#   FirstNames SecondNames  Age HighSchools
# A     Wabuko       Basil   21      Mabole
# B      Adams        Phil   26      Butere
# C     Trenda      Sherry   55      Mukumu
# D     Amanda        Lynn   19   Nyabururu
# E    Raymond     Malachi   69     Nairobi

# %%
test2 = pd.DataFrame({
    "FirstNames": ["Wabuko", "Adams", "Trenda", "Amanda", "Raymond"],
    "SecondNames": ["Basil", "Phil", "Sherry", "Lynn", "Malachi"],
    "Positions": [1, 4, 8, 3, 5],
    "Courses": ["Computer Science", "BioChemistry", "Pharmacy", "Mass Media", "Biotechnology"]
}, index=["A", "B", "C", "D", "E"])
test2
# Out:
#   FirstNames SecondNames  Positions           Courses
# A     Wabuko       Basil          1  Computer Science
# B      Adams        Phil          4      BioChemistry
# C     Trenda      Sherry          8          Pharmacy
# D     Amanda        Lynn          3        Mass Media
# E    Raymond     Malachi          5     Biotechnology

# %%
merging = pd.merge(test, test2, on=["SecondNames", "FirstNames"])
#Sortinf values in ascending/descending order
#merging.sort_values(['SecondNames', 'FirstNames'], ascending=True)
#hfg = merging.loc[merging['Age'] > 30, ['FirstNames', 'SecondNames', 'Courses']]
#hfg
merging['Positions'].sum()
# Out:
# 21

# %%
merging.iloc[2, 1]
# Out:
# 'Sherry'

# %%
merging.describe()
# Out:
#              Age  Positions
# count   5.000000   5.000000
# mean   38.000000   4.200000
# std    22.605309   2.588436
# min    19.000000   1.000000
# 25%    21.000000   3.000000
# 50%    26.000000   4.000000
# 75%    55.000000   5.000000
# max    69.000000   8.000000

# %%
#merging['Courses']

# %%
from statistics import *
x = [3, 4, 5, 8, 3, 2, 1]
y = [7, 8, 9, 0, 4, 3, 2]

plt.figure(1)
plt.subplot(2, 2, 1)
plt.plot(x, y, "b", label="Axis")

plt.subplot(2, 2, 2)
plt.plot(x, y, "g:", label="Axis")

plt.figure(2)
plt.subplot()
plt.plot(x, y, 'k-', label="Axis")

plt.legend()
plt.show()

# %%
cccv = pd.Series([1, 2, 3, 4, 5, np.nan, 6, None, 7, 8])
cccv
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# 5    NaN
# 6    6.0
# 7    NaN
# 8    7.0
# 9    8.0
# dtype: float64

# %%
cccv.fillna(method="ffill")
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# 5    5.0
# 6    6.0
# 7    6.0
# 8    7.0
# 9    8.0
# dtype: float64

# %%
titanic = pd.read_csv(r'E:\Windows10\documents\programming languages\python\CSV\serious-injury-outcome-indicators-2000-2020-CSV.csv')
titanic.head()
# Out:
#   Series_reference   Period            Type  Data_value   Lower_CI   Upper_CI  \
# 0            W_A11  2000-02  Moving average   59.666667  50.925823  68.407510
# 1            W_A11  2001-03  Moving average   60.000000  51.234775  68.765225
# 2            W_A11  2002-04  Moving average   59.000000  50.308125  67.691875
# 3            W_A11  2003-05  Moving average   59.000000  50.308125  67.691875
# 4            W_A11  2004-06  Moving average   61.333333  52.471252  70.195415
#
#       Units Indicator    Cause Validation Population       Age Severity
# 0  Injuries    Number  Assault  Validated  Whole pop  All ages    Fatal
# 1  Injuries    Number  Assault  Validated  Whole pop  All ages    Fatal
# 2  Injuries    Number  Assault  Validated  Whole pop  All ages    Fatal
# 3  Injuries    Number  Assault  Validated  Whole pop  All ages    Fatal
# 4  Injuries    Number  Assault  Validated  Whole pop  All ages    Fatal

# %%
titanic.loc[titanic['Severity'] != 'Fatal', ['Severity', 'Series_reference', 'Period', 'Data_value']]
titanic.fillna(method='ffill')
# Out:
#      Series_reference   Period            Type  Data_value   Lower_CI  \
# 0               W_A11  2000-02  Moving average   59.666667  50.925823
# 1               W_A11  2001-03  Moving average   60.000000  51.234775
# 2               W_A11  2002-04  Moving average   59.000000  50.308125
# 3               W_A11  2003-05  Moving average   59.000000  50.308125
# 4               W_A11  2004-06  Moving average   61.333333  52.471252
# ...               ...      ...             ...         ...        ...
# 2743              p21     2014     Single year   46.000000  32.706878
# 2744              p21     2015     Single year   41.000000  28.450107
# 2745              p21     2016     Single year   36.000000  24.240216
# 2746              p21     2017     Single year   40.000000  27.604099
# 2747              p21     2018     Single year   41.000000  28.450107
#
#        Upper_CI     Units Indicator       Cause Validation Population  \
# ...

# %%
partA = titanic.loc[titanic['Data_value']]
partB = titanic.loc[titanic['Lower_CI']]
partC = titanic.loc[titanic['Upper_CI']]
plt.plot(partA, partB, 'g:', xmax=100)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 partA = titanic.loc[titanic['Data_value']]
#       2 partB = titanic.loc[titanic['Lower_CI']]
#       3 partC = titanic.loc[titanic['Upper_CI']]
#
# File E:\AnacondaNew\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File E:\AnacondaNew\lib\site-packages\pandas\core\indexing.py:1191, in _LocIndexer._getitem_axis(self, key, axis)
#    1188     if hasattr(key, "ndim") and key.ndim > 1:
#    1189         raise ValueError("Cannot index with multidimensional key")
# -> 1191     return self._getitem_iterable(key, axis=axis)
#    1193 # nested tuple slicing
# ...

# %%
prac = pd.read_csv(r'E:\Windows10\documents\programming languages\python\CSV\local-authority-statistics-march-2022-quarter-csv.csv')
prac
# Out:
#      Series_reference   Period Reference_period  Data_value       STATUS  \
# 0         LASQ.SA1AZZ  1992.09        Quarterly        8461        Final
# 1         LASQ.SA1AZZ  1992.12        Quarterly       17144        Final
# 2         LASQ.SA1AZZ  1993.03        Quarterly        4597        Final
# 3         LASQ.SA1AZZ  1993.06        Quarterly       19710        Final
# 4         LASQ.SA1AZZ  1993.09        Quarterly       45352        Final
# ...               ...      ...              ...         ...          ...
# 3733      LASA.SARAZZ  2017.06           Annual     9584453        Final
# 3734      LASA.SARAZZ  2018.06           Annual    10052255        Final
# 3735      LASA.SARAZZ  2019.06           Annual    11163119        Final
# 3736      LASA.SARAZZ  2020.06           Annual    10994527        Final
# 3737      LASA.SARAZZ  2021.06           Annual    11577173  Provisional
#
#         UNITS  MAGNTUDE                           Subject             Group  \
# ...

# %%
shiet = pd.read_csv(r'E:\Windows10\documents\programming languages\python\CSV\detailed-household-expenditure-year-ended-June-2019-csv.csv')
shiet.fillna(method='bfill')
#shiet.loc[shiet['RSE'] != np.nan, ['RSE', 'Flag']]
# Out:
#       MsCode         HECCode      Estimate  RSE Flag
# 0       M003     Total Gross  2.441552e+09  2.7    R
# 1       M003       Total Net  2.370611e+09  2.7    R
# 2       M003               1  4.105492e+08  2.7    R
# 3       M003             1.1  4.136560e+07  2.7    R
# 4       M003         01.1.01  1.686880e+07  2.7    R
# ...      ...             ...           ...  ...  ...
# 11751   M004       14.9.03.0  4.500000e+00  NaN    M
# 11752   M004     14.9.03.0.0  4.500000e+00  NaN    M
# 11753   M004  14.9.03.0.0.69  5.000000e-01  NaN    L
# 11754   M004  14.9.03.0.0.79  4.100000e+00  NaN    S
# 11755   M004  14.9.03.0.0.89  4.100000e+00  NaN    M
#
# [11756 rows x 5 columns]

# %%
from sklearn.datasets import load_digits
digits = load_digits(n_class=6)
fig, ax = plt.subplots(8, 8, figsize=(6, 6))
for i, axi in enumerate ax.flat:
    axi.imshow(digits.images[i], cmap='binary')
    axi.set(xtics=[], yticks=[])
# Out:
#   Input In [18]
#     for i, axi in enumerate ax.flat:
#                             ^
# SyntaxError: invalid syntax

# %%
from sklearn.manifold import Isomap
iso = Isomap(n_components = 2)
projection = iso.fit_transform(digits.data)
plt.scatter(projection[:, 0], projection[:, 1], lw=0.1, c = digits.target, cmap=plt.cm.get_cmap('cubehelix', 6))
plt.colorbar(ticks=range(6), label='digit value')
plt.clim(-0.5, 5.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [19], in <cell line: 3>()
#       1 from sklearn.manifold import Isomap
#       2 iso = Isomap(n_components = 2)
# ----> 3 projection = iso.fit_transform(digits.data)
#       4 plt.scatter(projection[:, 0], projection[:, 1], lw=0.1, c = digits.target, cmap=plt.cm.get_cmap('cubehelix', 6))
#       5 plt.colorbar(ticks=range(6), label='digit value')
#
# NameError: name 'digits' is not defined

# %%
fig, ax = plt.subplots(5, 5, figsize=(5, 5))
fig.subplots_adjust(hspace=0, wspace=0)
#Getting some face data from Sikit Learn
from sklearn.datasets import fetch_olivetti_faces
faces = fetch_olivetti_faces().images
for i in range(5):
    for j in range(5):
        ax[i, j].xaxis.set_major_locater(plt.NullLocater())
        ax[i, j].yaxis.set_major_locater(plt.NullLocater())
        
    ax[i, j].imshow(faces[10 * i + j], cmap='bone')
        
plt.show()
# Out:
# downloading Olivetti faces from https://ndownloader.figshare.com/files/5976027 to C:\Users\BASIL\scikit_learn_data

# %%
from mpl_toolkits import mplot3d
ax = plt.axes(projection='3d')
x = [2, 3, 4, 6, 7, 0]
y = [3, 5, 2, 6, 9, 7]
z = [3, 4, 5, 7, 2, 6]
ax.plot3D(x, y, z)
plt.show()

# %%
def f(x, y):
    return np.sin(np.sqrt(x ** 2 + y ** 2))

x = np.linspace(-6, 6, 20)
y = np.linspace(-6, 6, 20)

x, y = np.meshgrid(x, y)
z = f(x, y)

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(x, y, z, 50, cmap='binary')

#ax.view_init(60, 35)# Viewing at different angles

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.title("3D Trial")

plt.show()

# %%
from mpl_toolkits.basemap import Basemap
plt.figure(figsize=(8, 8))
m = Basemap(projection='ortho', resolution=None, lat_0=50, lon_0=-100)
m.bluemarble(scale=0.5)

plt.show()

# %%
import seaborn as sns


dfg = [2, 3, 4, 2, 6, 8]
swe = [8, 4, 2, 6, 8, 3]

uoj = np.sin(dfg)
dft = np.sin(swe)

sns.set()
plt.plot(dfg, swe, uoj, dft)

plt.xlabel('x')
plt.ylabel('y')
plt.title('Seaborn')
plt.legend(['bottom', 'left'])

plt.show()

# %%
frhoi = plt.axes(projection='3d')
frhoi.plot3D()
plt.show()

# %%
# Requires internet connection.
iris = sns.load_dataset('iris')
iris

# %%
pd.__version__

# %%
ukg = pd.read_csv(r'E:\Pycharm&&PythonThings\Users\BASIL\PycharmProjects\Wabuko\python-project-color-detection\colors.csv')
print(ukg)

# %%
def Student_Names():
    count = 1
    while count <= 6:
        req = input(f"Student  {count} ,enter Your First Name: ")
        req2 = input("Enter Your Registration Number: ")
        req3 = int(input("Enter year of enrolment: "))
        print("Welcome " + req.title())
        
        count += 1
        

Student_Names()
# Out:
# Student  1 ,enter Your First Name: Basil
# Enter Your Registration Number: In13/00113/20
# Enter year of enrolment: 874
# Welcome Basil
# Student  2 ,enter Your First Name: gkbhnfd
# Enter Your Registration Number: 356ghf
# Enter year of enrolment: 3555
# Welcome Gkbhnfd
# Student  3 ,enter Your First Name: fdgh
# Enter Your Registration Number: 67
# Enter year of enrolment: 46577
# Welcome Fdgh
# Student  4 ,enter Your First Name: sdfg5
# Enter Your Registration Number: 6yhg
# Enter year of enrolment: 345
# Welcome Sdfg5
# Student  5 ,enter Your First Name: dfh
# Enter Your Registration Number: 56fyh
# Enter year of enrolment: 345
# Welcome Dfh
# Student  6 ,enter Your First Name: dhytr
# Enter Your Registration Number: 35gyjh
# Enter year of enrolment: 456
# Welcome Dhytr

# %%
def call_Student_Names():
    Student_Names()
    
call_Student_Names()
